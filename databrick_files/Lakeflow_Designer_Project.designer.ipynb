# %%
"""
id: source_0
template: source
name: customer_first
parentId: Raw Data
position:
  x: 30
  y: 78
description:
  text: Read all data from a parquet file.
  hash: 7635c6ec
previewCodeHash: 1a48338876a5dece
previewMode: full
config:
  file_source:
    path: /Volumes/databric_cata/raw/rawvolume/rawdata/customers/customer_first.parquet
    format: '"parquet"'
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/databric_cata/raw/rawvolume/rawdata/customers/customer_first.parquet",
        "format": "\"parquet\""
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_0.data"] = out["data"]

# %%
"""
id: source_1
template: source
name: orders_first
parentId: Raw Data
position:
  x: 30
  y: 233
description:
  text: Read all data from the specified parquet file.
  hash: 60f43b12
previewCodeHash: 7b693a8666857350
previewMode: "1000"
config:
  file_source:
    path: /Volumes/databric_cata/raw/rawvolume/rawdata/orders/orders_first.parquet
    format: '"parquet"'
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/databric_cata/raw/rawvolume/rawdata/orders/orders_first.parquet",
        "format": "\"parquet\""
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_1.data"] = out["data"]

# %%
"""
id: source_2
template: source
name: products_first
parentId: Raw Data
position:
  x: 30
  y: 388
description:
  text: Load all data from a Parquet file.
  hash: "607e9049"
previewCodeHash: 1c81826d0fc4e1ac
previewMode: "1000"
config:
  file_source:
    path: /Volumes/databric_cata/raw/rawvolume/rawdata/products/products_first.parquet
    format: '"parquet"'
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/databric_cata/raw/rawvolume/rawdata/products/products_first.parquet",
        "format": "\"parquet\""
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_2.data"] = out["data"]

# %%
"""
id: source_3
template: source
name: regions
parentId: Raw Data
position:
  x: 30
  y: 543
description:
  text: Load data from a parquet file.
  hash: 17e7d171
previewCodeHash: 7362c77712693d6c
previewMode: "1000"
config:
  file_source:
    path: /Volumes/databric_cata/raw/rawvolume/rawdata/regions/regions.parquet
    format: '"parquet"'
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/databric_cata/raw/rawvolume/rawdata/regions/regions.parquet",
        "format": "\"parquet\""
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_3.data"] = out["data"]

# %%
"""
id: output_customer_first_delta
template: python
name: customer_first_delta
parentId: Bronze_Layer
position:
  x: 30
  y: 78
description:
  text: Save data as Delta format in bronze volume.
  hash: 67925cd4
previewCodeHash: 32ccea6616573148
previewMode: "1000"
config:
  code: |
    # Store customer_first in Delta format in bronze_volume
    df = inputs["data"][0]
    bronze_path = "/Volumes/lake_cata/bronze/bronze_volume/customer_first"
    df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(bronze_path)
    print(f"Data successfully written to {bronze_path} in Delta format")
    print(f"Total rows written: {df.count()}")
    result = df
input:
  - node: source_0
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    # Store customer_first in Delta format in bronze_volume
    df = inputs["data"][0]
    bronze_path = "/Volumes/lake_cata/bronze/bronze_volume/customer_first"
    df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(bronze_path)
    print(f"Data successfully written to {bronze_path} in Delta format")
    print(f"Total rows written: {df.count()}")
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["source_0.data"]
    ],
    "data__sources": [
        {
            "node": "source_0",
            "output_port": "data",
            "name": "customer_first",
            "df_name": "customer_first"
        }
    ]
}
out = run(config, inputs, spark)
ctx["output_customer_first_delta.result"] = out["result"]

# %%
"""
id: output_customer_first_delta_copy
template: python
name: order_first_delta_
parentId: Bronze_Layer
position:
  x: 30
  y: 233
description:
  text: Save customer data in Delta format at specified location, replacing existing data.
  hash: 27b41354
previewCodeHash: 688bb4534fecdb3e
previewMode: "1000"
config:
  code: |
    # Store customer_first in Delta format in bronze_volume
    df = inputs["data"][0]
    bronze_path = "/Volumes/lake_cata/bronze/bronze_volume/orders_first"
    df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(bronze_path)
    print(f"Data successfully written to {bronze_path} in Delta format")
    print(f"Total rows written: {df.count()}")
    result = df
input:
  - node: source_1
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    # Store customer_first in Delta format in bronze_volume
    df = inputs["data"][0]
    bronze_path = "/Volumes/lake_cata/bronze/bronze_volume/orders_first"
    df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(bronze_path)
    print(f"Data successfully written to {bronze_path} in Delta format")
    print(f"Total rows written: {df.count()}")
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["source_1.data"]
    ],
    "data__sources": [
        {
            "node": "source_1",
            "output_port": "data",
            "name": "orders_first",
            "df_name": "orders_first"
        }
    ]
}
out = run(config, inputs, spark)
ctx["output_customer_first_delta_copy.result"] = out["result"]

# %%
"""
id: output_customer_first_delta_copy_copy
template: python
name: products_first_delta
parentId: Bronze_Layer
position:
  x: 30
  y: 388
description:
  text: Save data to Delta format in bronze_volume folder, replacing existing data.
  hash: 3b98d223
previewCodeHash: e8b7e727838787b1
previewMode: "1000"
config:
  code: |
    # Store customer_first in Delta format in bronze_volume
    df = inputs["data"][0]
    bronze_path = "/Volumes/lake_cata/bronze/bronze_volume/Products_first"
    df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(bronze_path)
    print(f"Data successfully written to {bronze_path} in Delta format")
    print(f"Total rows written: {df.count()}")
    result = df
input:
  - node: source_2
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    # Store customer_first in Delta format in bronze_volume
    df = inputs["data"][0]
    bronze_path = "/Volumes/lake_cata/bronze/bronze_volume/Products_first"
    df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(bronze_path)
    print(f"Data successfully written to {bronze_path} in Delta format")
    print(f"Total rows written: {df.count()}")
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["source_2.data"]
    ],
    "data__sources": [
        {
            "node": "source_2",
            "output_port": "data",
            "name": "products_first",
            "df_name": "products_first"
        }
    ]
}
out = run(config, inputs, spark)
ctx["output_customer_first_delta_copy_copy.result"] = out["result"]

# %%
"""
id: output_customer_first_delta_copy_copy_copy
template: python
name: Region_first_delta
parentId: Bronze_Layer
position:
  x: 30
  y: 543
description:
  text: Save data as Delta files in the bronze_volume storage path, replacing existing data.
  hash: 1494c6bf
previewCodeHash: 87d39299b6e42c06
previewMode: "1000"
config:
  code: |
    # Store customer_first in Delta format in bronze_volume
    df = inputs["data"][0]
    bronze_path = "/Volumes/lake_cata/bronze/bronze_volume/Region_first"
    df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(bronze_path)
    print(f"Data successfully written to {bronze_path} in Delta format")
    print(f"Total rows written: {df.count()}")
    result = df
input:
  - node: source_3
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    # Store customer_first in Delta format in bronze_volume
    df = inputs["data"][0]
    bronze_path = "/Volumes/lake_cata/bronze/bronze_volume/Region_first"
    df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(bronze_path)
    print(f"Data successfully written to {bronze_path} in Delta format")
    print(f"Total rows written: {df.count()}")
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["source_3.data"]
    ],
    "data__sources": [
        {
            "node": "source_3",
            "output_port": "data",
            "name": "regions",
            "df_name": "regions"
        }
    ]
}
out = run(config, inputs, spark)
ctx["output_customer_first_delta_copy_copy_copy.result"] = out["result"]

# %%
"""
id: transform_10
template: transform
name: transform_customer
parentId: Silver_Layer
position:
  x: 30
  y: 78
description:
  text: Create full name, extract email domain, and keep customer details.
  hash: ea01679f
previewCodeHash: 11fd560039cd5c56
previewMode: "1000"
config:
  expressions:
    - CONCAT(first_name, ' ', last_name) `full_name`
    - SUBSTRING(email, instr(email, '@') + 1) `email_domain`
    - customer_id
    - first_name
    - last_name
    - email
    - city
    - state
input:
  - node: output_customer_first_delta
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "CONCAT(first_name, ' ', last_name) `full_name`",
        "SUBSTRING(email, instr(email, '@') + 1) `email_domain`",
        "customer_id",
        "first_name",
        "last_name",
        "email",
        "city",
        "state"
    ]
}
inputs = {
    "data": ctx["output_customer_first_delta.result"]
}
out = run(config, inputs, spark)
ctx["transform_10.transformed_data"] = out["transformed_data"]

# %%
"""
id: transform_11
template: transform
name: transform_orders
parentId: Silver_Layer
position:
  x: 30
  y: 233
description:
  text: Remove the _rescued_data column and calculate total value by multiplying quantity and total amount.
  hash: c6d53160
previewCodeHash: 7d82a1b77e2ca381
previewMode: "1000"
config:
  expressions:
    - "* EXCEPT(_rescued_data)"
    - quantity * total_amount AS `total_value`
input:
  - node: output_customer_first_delta_copy
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "* EXCEPT(_rescued_data)",
        "quantity * total_amount AS `total_value`"
    ]
}
inputs = {
    "data": ctx["output_customer_first_delta_copy.result"]
}
out = run(config, inputs, spark)
ctx["transform_11.transformed_data"] = out["transformed_data"]

# %%
"""
id: transform_12
template: transform
name: transform_products
parentId: Silver_Layer
position:
  x: 30
  y: 388
description:
  text: Keep all columns except _rescued_data and add a new combined brand-category column.
  hash: 6369b93c
previewCodeHash: d8d106beb24ada91
previewMode: "1000"
config:
  expressions:
    - "* EXCEPT(_rescued_data)"
    - CONCAT(brand, '-', category) AS `brand_category`
input:
  - node: output_customer_first_delta_copy_copy
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "* EXCEPT(_rescued_data)",
        "CONCAT(brand, '-', category) AS `brand_category`"
    ]
}
inputs = {
    "data": ctx["output_customer_first_delta_copy_copy.result"]
}
out = run(config, inputs, spark)
ctx["transform_12.transformed_data"] = out["transformed_data"]

# %%
"""
id: transform_13
template: transform
name: transform_region
parentId: Silver_Layer
position:
  x: 30
  y: 543
description:
  text: Remove the column named _rescued_data.
  hash: 16aca4ae
previewCodeHash: 12ade9174db4b147
previewMode: "1000"
config:
  expressions:
    - "* EXCEPT(_rescued_data)"
input:
  - node: output_customer_first_delta_copy_copy_copy
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "* EXCEPT(_rescued_data)"
    ]
}
inputs = {
    "data": ctx["output_customer_first_delta_copy_copy_copy.result"]
}
out = run(config, inputs, spark)
ctx["transform_13.transformed_data"] = out["transformed_data"]

# %%
"""
id: silver_join_customer_orders
template: join
name: silver_join_customer_orders
parentId: Silver_Layer
position:
  x: 264.12732789919596
  y: 155.5
description:
  text: Combine customer and order data on customer ID, keeping specific customer and order details.
  hash: afff60f4
previewCodeHash: 0b69d3339e6d4440
previewMode: "1000"
config:
  join_type: inner
  join_conditions: left.customer_id = right.customer_id
  expressions:
    - "`left`.full_name"
    - "`left`.email_domain"
    - "`left`.customer_id `customer_id`"
    - "`left`.first_name"
    - "`left`.last_name"
    - "`left`.email"
    - "`left`.city"
    - "`left`.state"
    - "`right`.order_id"
    - "`right`.customer_id `right_customer_id`"
    - "`right`.product_id"
    - "`right`.order_date"
    - "`right`.quantity"
    - "`right`.total_amount"
    - "`right`.total_value"
input:
  - node: transform_10
    input_port: left
    output_port: transformed_data
  - node: transform_11
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    # Alias DataFrames with fixed names so that table-qualified column
    # references in join_conditions and expressions always resolve.
    # The TS serializer emits "left.col" / "right.col" regardless of the
    # actual table names, so these aliases must match exactly.
    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    # join_condition is a plain SQL expression string serialized by the TS
    # side (same pattern as filter's condition field).
    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)

    # Apply optional SELECT expressions
    if expressions:
        result = result.selectExpr(*expressions)

    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "inner",
    "join_conditions": "left.customer_id = right.customer_id",
    "expressions": [
        "`left`.full_name",
        "`left`.email_domain",
        "`left`.customer_id `customer_id`",
        "`left`.first_name",
        "`left`.last_name",
        "`left`.email",
        "`left`.city",
        "`left`.state",
        "`right`.order_id",
        "`right`.customer_id `right_customer_id`",
        "`right`.product_id",
        "`right`.order_date",
        "`right`.quantity",
        "`right`.total_amount",
        "`right`.total_value"
    ]
}
inputs = {
    "left": ctx["transform_10.transformed_data"],
    "right": ctx["transform_11.transformed_data"]
}
out = run(config, inputs, spark)
ctx["silver_join_customer_orders.joined_data"] = out["joined_data"]

# %%
"""
id: silver_merge_products_region
template: join
name: silver_merge_products_region
parentId: Silver_Layer
position:
  x: 275.6550455168367
  y: 467.1468168025201
description:
  text: Combine two datasets using an inner join with a condition that always matches, keeping all columns from both.
  hash: ee7c71af
previewCodeHash: e97ef1f8c934e47d
previewMode: "1000"
config:
  join_type: inner
  join_conditions: 1 = 1
  expressions: []
input:
  - node: transform_12
    input_port: left
    output_port: transformed_data
  - node: transform_13
    input_port: right
    output_port: transformed_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    # Alias DataFrames with fixed names so that table-qualified column
    # references in join_conditions and expressions always resolve.
    # The TS serializer emits "left.col" / "right.col" regardless of the
    # actual table names, so these aliases must match exactly.
    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    # join_condition is a plain SQL expression string serialized by the TS
    # side (same pattern as filter's condition field).
    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)

    # Apply optional SELECT expressions
    if expressions:
        result = result.selectExpr(*expressions)

    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "inner",
    "join_conditions": "1 = 1",
    "expressions": []
}
inputs = {
    "left": ctx["transform_12.transformed_data"],
    "right": ctx["transform_13.transformed_data"]
}
out = run(config, inputs, spark)
ctx["silver_merge_products_region.joined_data"] = out["joined_data"]

# %%
"""
id: silver_join_customer_orders_delta
template: python
name: silver_join_customer_orders_delta
parentId: Silver_Layer
position:
  x: 531.1909918487938
  y: 163.73408401260053
description:
  text: Save data as Delta format file and overwrite existing data.
  hash: 7c3c252c
previewCodeHash: bf2812b329c67a59
previewMode: "1000"
config:
  code: |
    # Store silver_join_customer_orders in Delta format in silver_volume
    df = inputs["data"][0]
    silver_path = "/Volumes/lake_cata/silver/silver_volume/silver_join_customer_orders"
    df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(silver_path)
    print(f"Data successfully written to {silver_path} in Delta format")
    print(f"Total rows written: {df.count()}")
    result = df
input:
  - node: silver_join_customer_orders
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    # Store silver_join_customer_orders in Delta format in silver_volume
    df = inputs["data"][0]
    silver_path = "/Volumes/lake_cata/silver/silver_volume/silver_join_customer_orders"
    df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(silver_path)
    print(f"Data successfully written to {silver_path} in Delta format")
    print(f"Total rows written: {df.count()}")
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["silver_join_customer_orders.joined_data"]
    ],
    "data__sources": [
        {
            "node": "silver_join_customer_orders",
            "output_port": "joined_data",
            "name": "silver_join_customer_orders",
            "df_name": "silver_join_customer_orders"
        }
    ]
}
out = run(config, inputs, spark)
ctx["silver_join_customer_orders_delta.result"] = out["result"]

# %%
"""
id: obt
template: join
name: obt
parentId: Gold_Layer
position:
  x: 30
  y: 78
description:
  text: Combine customer orders with product details using all rows from both sides, keeping selected columns from each.
  hash: 3528ed35
previewCodeHash: b0ac5bfabe6233c0
previewMode: "1000"
config:
  join_type: inner
  join_conditions: 1 = 1
  expressions:
    - "`left`.full_name"
    - "`left`.email_domain"
    - "`left`.customer_id"
    - "`left`.first_name"
    - "`left`.last_name"
    - "`left`.email"
    - "`left`.city"
    - "`left`.state"
    - "`left`.order_id"
    - "`left`.right_customer_id"
    - "`left`.product_id `product_id`"
    - "`left`.order_date"
    - "`left`.quantity"
    - "`left`.total_amount"
    - "`left`.total_value"
    - "`right`.product_id `right_product_id`"
    - "`right`.product_name"
    - "`right`.category"
    - "`right`.brand"
    - "`right`.price"
    - "`right`.brand_category"
    - "`right`.region_id"
    - "`right`.region"
input:
  - node: silver_join_customer_orders
    input_port: left
    output_port: joined_data
  - node: silver_merge_products_region
    input_port: right
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    # Alias DataFrames with fixed names so that table-qualified column
    # references in join_conditions and expressions always resolve.
    # The TS serializer emits "left.col" / "right.col" regardless of the
    # actual table names, so these aliases must match exactly.
    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    # join_condition is a plain SQL expression string serialized by the TS
    # side (same pattern as filter's condition field).
    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)

    # Apply optional SELECT expressions
    if expressions:
        result = result.selectExpr(*expressions)

    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "inner",
    "join_conditions": "1 = 1",
    "expressions": [
        "`left`.full_name",
        "`left`.email_domain",
        "`left`.customer_id",
        "`left`.first_name",
        "`left`.last_name",
        "`left`.email",
        "`left`.city",
        "`left`.state",
        "`left`.order_id",
        "`left`.right_customer_id",
        "`left`.product_id `product_id`",
        "`left`.order_date",
        "`left`.quantity",
        "`left`.total_amount",
        "`left`.total_value",
        "`right`.product_id `right_product_id`",
        "`right`.product_name",
        "`right`.category",
        "`right`.brand",
        "`right`.price",
        "`right`.brand_category",
        "`right`.region_id",
        "`right`.region"
    ]
}
inputs = {
    "left": ctx["silver_join_customer_orders.joined_data"],
    "right": ctx["silver_merge_products_region.joined_data"]
}
out = run(config, inputs, spark)
ctx["obt.joined_data"] = out["joined_data"]

# %%
"""
id: silver_merge_products_region_delta
template: python
name: silver_merge_products_region_delta
parentId: Silver_Layer
position:
  x: 529.5441750462735
  y: 468.7936336050402
description:
  text: Save data as Delta table to silver_volume location, replacing existing data.
  hash: 12d2ffe4
previewCodeHash: 4efacb6fe66ecb64
previewMode: "1000"
config:
  code: |
    # Store silver_merge_products_region in Delta format in silver_volume
    df = inputs["data"][0]
    silver_path = "/Volumes/lake_cata/silver/silver_volume/silver_merge_products_region"
    df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(silver_path)
    print(f"Data successfully written to {silver_path} in Delta format")
    print(f"Total rows written: {df.count()}")
    result = df
input:
  - node: silver_merge_products_region
    input_port: data
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    # Store silver_merge_products_region in Delta format in silver_volume
    df = inputs["data"][0]
    silver_path = "/Volumes/lake_cata/silver/silver_volume/silver_merge_products_region"
    df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(silver_path)
    print(f"Data successfully written to {silver_path} in Delta format")
    print(f"Total rows written: {df.count()}")
    result = df

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["silver_merge_products_region.joined_data"]
    ],
    "data__sources": [
        {
            "node": "silver_merge_products_region",
            "output_port": "joined_data",
            "name": "silver_merge_products_region",
            "df_name": "silver_merge_products_region"
        }
    ]
}
out = run(config, inputs, spark)
ctx["silver_merge_products_region_delta.result"] = out["result"]

# %% [markdown]
# ---
# id: Raw Data
# template: group
# name: Raw Data
# position:
#   x: 0
#   y: 0
# dimensions:
#   width: 260
#   height: 668
# ---

# %% [markdown]
# ---
# id: Bronze_Layer
# template: group
# name: Bronze_Layer
# position:
#   x: 360
#   y: 0
# dimensions:
#   width: 260
#   height: 668
# ---

# %% [markdown]
# ---
# id: Silver_Layer
# template: group
# name: Silver_Layer
# position:
#   x: 720
#   y: 0
# dimensions:
#   width: 761.1909918487938
#   height: 668
# ---

# %% [markdown]
# ---
# id: Gold_Layer
# template: group
# name: Gold_Layer
# position:
#   x: 1555.6652685886565
#   y: 245.67453442016085
# dimensions:
#   width: 260
#   height: 203
# ---
